# %% [markdown]
# <pre>
# <center><b><h1>Machine Learning</b></center>
#
# <center><b><h1>Lab - 3</b></center>
# <center><b><h1>23010101193 | 10-12-2025</b></center>
# <pre>

# %% [markdown]
# # 📱 Lab: Scikit-Learn Fundamentals (Google Play Store)
#
# **Objective:** Transition from manual data cleaning to automated Machine Learning preprocessing using Scikit-Learn.
#
# **Prerequisites:**
# * Ensure you have the `googleplaystore_cleaned.csv` file (from the previous lab) in this folder.

# %% [markdown]
# ### 1. Load Preprocessed Data
# **Instruction:** Load the dataset you cleaned in the previous lab. This dataset should already have `Installs`, `Price`, and `Reviews` converted to numbers.

# %%
import pandas as pd
data = pd.read_csv("googleplaystore_cleaned.csv")
data
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10345       10836                                   Sya9a Maroc - FR
# 10346       10837                   Fr. Mike Schmitz Audio Teachings
# 10347       10838                             Parkinson Exercices FR
# 10348       10839                      The SCP Foundation DB fr nn5n
# 10349       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating Reviews        Size  Installs  Type Price  \
# 0           ART_AND_DESIGN     4.1     159  19000000.0     10000  Free     0
# 1           ART_AND_DESIGN     3.9     967  14000000.0    500000  Free     0
# 2           ART_AND_DESIGN     4.7   87510   8700000.0   5000000  Free     0
# 3           ART_AND_DESIGN     4.5  215644  25000000.0  50000000  Free     0
# 4           ART_AND_DESIGN     4.3     967   2800000.0    100000  Free     0
# ...                    ...     ...     ...         ...       ...   ...   ...
# 10345               FAMILY     4.5      38  53000000.0      5000  Free     0
# 10346               FAMILY     5.0       4   3600000.0       100  Free     0
# 10347              MEDICAL     4.3       3   9500000.0      1000  Free     0
# 10348  BOOKS_AND_REFERENCE     4.5     114         NaN      1000  Free     0
# 10349            LIFESTYLE     4.5  398307  19000000.0  10000000  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10345       Everyone                  Education     July 25, 2017
# 10346       Everyone                  Education      July 6, 2018
# 10347       Everyone                    Medical  January 20, 2017
# 10348     Mature 17+          Books & Reference  January 19, 2015
# 10349       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10345                1.48          4.1 and up
# 10346                 1.0          4.1 and up
# 10347                 1.0          2.2 and up
# 10348  Varies with device  Varies with device
# 10349  Varies with device  Varies with device
#
# [10350 rows x 14 columns]

# %% [markdown]
# ### Intro to Scikit-Learn
# **What is Scikit-Learn?**
# It is the standard library for Machine Learning in Python. We use it for:
# 1.  **Preprocessing:** Scaling numbers and encoding text.
# 2.  **Modeling:** Training algorithms.
# 3.  **Evaluation:** Checking accuracy.
#
# **Task:** Import `sklearn` and check the version.

# %%
import sklearn as sk

# %%
##__version__
sk.__version__
# Out:
# '1.6.1'

# %% [markdown]
# ### 3.  Train_Test_Split
# **Concept:** We split data to prevent "Overfitting". The model learns from the **Train** set and is tested on the **Test** set.
#
# **Task:**
# 1. Define `X` (Features: everything except Rating/App) and `y` (Target: Rating).
# 2. Split the data (80% Train, 20% Test).

# %%
# train_test_split
x = data.drop(['Rating','App'],axis=1)
y = data['Rating']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (8280, 12)

# %%
x_test.shape
# Out:
# (2070, 12)

# %%
y_train.shape
# Out:
# (8280,)

# %%
y_test.shape
# Out:
# (2070,)

# %% [markdown]
# ### 4. 📏 Scaling Numerical Data (StandardScaler)
# **Concept:** `Installs` (Millions) are much larger than `Rating` (1-5). We scale them so the model treats them equally.
#
# **Task:** Use `StandardScaler` on the numerical columns.

# %%
#StandardScaler()
#fit_transform()

data['Installs']=pd.to_numeric(data['Installs'],errors="coerce")

from sklearn.preprocessing import StandardScaler
cols=['Installs','Rating']
s=StandardScaler()
data[cols]=s.fit_transform(data[cols])
data
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10345       10836                                   Sya9a Maroc - FR
# 10346       10837                   Fr. Mike Schmitz Audio Teachings
# 10347       10838                             Parkinson Exercices FR
# 10348       10839                      The SCP Foundation DB fr nn5n
# 10349       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category    Rating Reviews        Size  Installs  Type  \
# 0           ART_AND_DESIGN -0.204541     159  19000000.0 -0.176396  Free
# 1           ART_AND_DESIGN -0.598492     967  14000000.0 -0.170291  Free
# 2           ART_AND_DESIGN  0.977313   87510   8700000.0 -0.114227  Free
# 3           ART_AND_DESIGN  0.583362  215644  25000000.0  0.446410  Free
# 4           ART_AND_DESIGN  0.189411     967   2800000.0 -0.175275  Free
# ...                    ...       ...     ...         ...       ...   ...
# 10345               FAMILY  0.583362      38  53000000.0 -0.176458  Free
# 10346               FAMILY  1.568239       4   3600000.0 -0.176519  Free
# 10347              MEDICAL  0.189411       3   9500000.0 -0.176508  Free
# 10348  BOOKS_AND_REFERENCE  0.583362     114         NaN -0.176508  Free
# 10349            LIFESTYLE  0.583362  398307  19000000.0 -0.051934  Free
#
#       Price Content Rating                     Genres      Last Updated  \
# 0         0       Everyone               Art & Design   January 7, 2018
# 1         0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2         0       Everyone               Art & Design    August 1, 2018
# 3         0           Teen               Art & Design      June 8, 2018
# 4         0       Everyone    Art & Design;Creativity     June 20, 2018
# ...     ...            ...                        ...               ...
# 10345     0       Everyone                  Education     July 25, 2017
# 10346     0       Everyone                  Education      July 6, 2018
# 10347     0       Everyone                    Medical  January 20, 2017
# 10348     0     Mature 17+          Books & Reference  January 19, 2015
# 10349     0       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10345                1.48          4.1 and up
# 10346                 1.0          4.1 and up
# 10347                 1.0          2.2 and up
# 10348  Varies with device  Varies with device
# 10349  Varies with device  Varies with device
#
# [10350 rows x 14 columns]

# %% [markdown]
# ### 5. 🔠 Encoding Categorical Data
# **Concept:** Models need numbers, not text like "Business" or "Teen".
#
# **Method A: Pandas `get_dummies` (Simple)**

# %%
#get_dummies

# %%
encoded_data = pd.get_dummies(data, columns=['Category'])
encoded_data
# Out:
#        Unnamed: 0                                                App  \
# 0               0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1               1                                Coloring book moana
# 2               2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3               3                              Sketch - Draw & Paint
# 4               4              Pixel Draw - Number Art Coloring Book
# ...           ...                                                ...
# 10345       10836                                   Sya9a Maroc - FR
# 10346       10837                   Fr. Mike Schmitz Audio Teachings
# 10347       10838                             Parkinson Exercices FR
# 10348       10839                      The SCP Foundation DB fr nn5n
# 10349       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#          Rating Reviews        Size  Installs  Type Price Content Rating  \
# 0     -0.204541     159  19000000.0 -0.176396  Free     0       Everyone
# 1     -0.598492     967  14000000.0 -0.170291  Free     0       Everyone
# 2      0.977313   87510   8700000.0 -0.114227  Free     0       Everyone
# 3      0.583362  215644  25000000.0  0.446410  Free     0           Teen
# 4      0.189411     967   2800000.0 -0.175275  Free     0       Everyone
# ...         ...     ...         ...       ...   ...   ...            ...
# 10345  0.583362      38  53000000.0 -0.176458  Free     0       Everyone
# 10346  1.568239       4   3600000.0 -0.176519  Free     0       Everyone
# 10347  0.189411       3   9500000.0 -0.176508  Free     0       Everyone
# 10348  0.583362     114         NaN -0.176508  Free     0     Mature 17+
# 10349  0.583362  398307  19000000.0 -0.051934  Free     0       Everyone
#
#                           Genres  ... Category_PERSONALIZATION  \
# 0                   Art & Design  ...                    False
# 1      Art & Design;Pretend Play  ...                    False
# 2                   Art & Design  ...                    False
# 3                   Art & Design  ...                    False
# 4        Art & Design;Creativity  ...                    False
# ...                          ...  ...                      ...
# 10345                  Education  ...                    False
# 10346                  Education  ...                    False
# 10347                    Medical  ...                    False
# 10348          Books & Reference  ...                    False
# 10349                  Lifestyle  ...                    False
#
#       Category_PHOTOGRAPHY Category_PRODUCTIVITY  Category_SHOPPING  \
# 0                    False                 False              False
# 1                    False                 False              False
# 2                    False                 False              False
# 3                    False                 False              False
# 4                    False                 False              False
# ...                    ...                   ...                ...
# 10345                False                 False              False
# 10346                False                 False              False
# 10347                False                 False              False
# 10348                False                 False              False
# 10349                False                 False              False
#
#        Category_SOCIAL  Category_SPORTS  Category_TOOLS  \
# 0                False            False           False
# 1                False            False           False
# 2                False            False           False
# 3                False            False           False
# 4                False            False           False
# ...                ...              ...             ...
# 10345            False            False           False
# 10346            False            False           False
# 10347            False            False           False
# 10348            False            False           False
# 10349            False            False           False
#
#        Category_TRAVEL_AND_LOCAL  Category_VIDEO_PLAYERS  Category_WEATHER
# 0                          False                   False             False
# 1                          False                   False             False
# 2                          False                   False             False
# 3                          False                   False             False
# 4                          False                   False             False
# ...                          ...                     ...               ...
# 10345                      False                   False             False
# 10346                      False                   False             False
# 10347                      False                   False             False
# 10348                      False                   False             False
# 10349                      False                   False             False
#
# [10350 rows x 47 columns]

# %% [markdown]
# **Method B: Sklearn `OneHotEncoder` (Professional)**

# %%
# #OneHotEncoder
# from sklearn.preprocessing import OneHotEncoder
# cols=['Category','Genres']
# o=OneHotEncoder()
# data[cols]=s.fit_transform(data[cols])
# data
# #fit_transform

# %% [markdown]
# ### 6. 🚀 The Full Pipeline: ColumnTransformer
# **Concept:** Instead of doing steps 4 and 5 manually, we wrap them in one object.
#
# **Task:** Create a `ColumnTransformer` that Scales numerical data AND Encodes categorical data at the same time.

# %%
from sklearn.compose import ColumnTransformer

# %%
numeric_features = ['Reviews', 'Size', 'Installs', 'Price']
categorical_features = ['Category', 'Content Rating']

# %%
# Create ColumnTransformer

# %%
from sklearn.pipeline import Pipeline
